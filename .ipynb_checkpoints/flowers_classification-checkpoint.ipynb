# %% [markdown]
# ## 0. Load Libraries and Data
#
# Each kind of flowers are having their own distinctive features which distinguish them with other species. Those features such as colors, sepals, petals, stamens (anther and filament), and carpels (stigma, style, ovary). Images from five kinds of flowers are provided in training and test dataset, there are daisy, sunflower, dandelion, rose, and tulip. With Convolutional Neural Network, we can build an image classification model to classify an image flower to one of these flower species.
#
# https://medium.com/@sidathasiri/building-a-convolutional-neural-network-for-image-classification-with-tensorflow-f1f2f56bd83b
# https://www.guru99.com/convnet-tensorflow-image-classification.html
# https://towardsdatascience.com/using-convolutional-neural-network-for-image-classification-5997bfd0ede4
# https://medium.com/analytics-vidhya/cnn-german-traffic-signal-recognition-benchmarking-using-tensorflow-accuracy-80-d069b7996082

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
#import seaborn as sns
import os
#import cv2

# For Neural Network
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras import optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator, DirectoryIterator

import warnings
warnings.filterwarnings("ignore")
# Out:
# 2023-01-08 06:43:01.197110: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
tf.__version__
# Out:
# '2.9.1'

# %%
train_dir = './train'
test_dir = './test'

# %% [markdown]
# ## 1. Exploratory Data Analysis

# %%
# Visualizing 25 random images from test data
import random
from matplotlib.image import imread
import os

# %%
flowers_var = os.listdir(train_dir)

count_flowers_train = []
count_flowers_test = []

for i in range(len(flowers_var)):
    len_train_imgs = len(os.listdir(train_dir + '/' + flowers_var[i]))
    len_test_imgs = len(os.listdir(test_dir + '/' + flowers_var[i]))
    count_flowers_train.append(len_train_imgs)
    count_flowers_test.append(len_test_imgs)

summary_df = pd.DataFrame(list(zip(count_flowers_train, count_flowers_test)),
               columns =['train_len', 'test_len'], index = flowers_var)
summary_df.plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Rescaling Image

# %%
datagen = ImageDataGenerator(rescale=1/255.) 

datatrain = datagen.flow_from_directory(train_dir,
                                        target_size=(150, 150),
                                        batch_size=32,
                                        class_mode='categorical',
                                        shuffle = True)

datatest = datagen.flow_from_directory(test_dir,
                                       target_size=(150, 150),
                                       batch_size=32,
                                       class_mode='categorical',
                                       shuffle = False)
# Out:
# Found 3762 images belonging to 5 classes.
# Found 555 images belonging to 5 classes.

# %%
print("classes:", datatrain.class_indices)
print("how many batches:", len(datatrain)) 

for image_batch, labels_batch in datatrain:
    print("n-batch, length, width, channel (RGB):", image_batch.shape)
    print("example label:", labels_batch[0])
    plt.figure(figsize=(25,25))
    
    for i in range(len(image_batch)):
        plt.subplot(8,4,i+1)
        plt.imshow(image_batch[i])
    
    break
# Out:
# classes: {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}
# how many batches: 118
# n-batch, length, width, channel (RGB): (32, 150, 150, 3)
# example label: [1. 0. 0. 0. 0.]

# %% [markdown]
# ## 2. CNN Model

# %%
import tensorflow as tf
from tensorflow.keras import Sequential, layers
from tensorflow.keras.applications.xception import Xception, preprocess_input

# %%
X, y = next(datatrain)

# %% [markdown]
# ### a. Using Xception as Base Model

# %%
base_model = Xception(
    weights='imagenet',
    include_top=False,
    input_shape=(150, 150, 3)
)
base_model.trainable = False

inputs = keras.Input(shape=(150, 150, 3))

base = base_model(inputs, training=False)

vectors = keras.layers.GlobalAveragePooling2D()(base)

outputs = keras.layers.Dense(5)(vectors)

model = keras.Model(inputs, outputs)
# Out:
# 2023-01-08 06:46:52.420871: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-08 06:46:52.485789: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-08 06:46:52.486519: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-08 06:46:52.487644: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# ...

# %%
learning_rate = 0.01
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
loss = keras.losses.CategoricalCrossentropy(from_logits=True)
model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

# %%
history = model.fit(datatrain, epochs=10, validation_data=datatest)
# Out:
# Epoch 1/20
# 2023-01-08 06:47:54.733853: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 2023-01-08 06:47:56.954394: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-01-08 06:47:56.955675: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-01-08 06:47:56.955724: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2023-01-08 06:47:56.957220: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-01-08 06:47:56.957425: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# ...

# %%
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.xticks(np.arange(10))
plt.legend()

# %% [markdown]
# ## Adjusting Learning Rate

# %%
def make_model(learning_rate=0.01):
    base_model = Xception(
        weights='imagenet',
        include_top=False,
        input_shape=(150, 150, 3)
    )

    base_model.trainable = False

    inputs = keras.Input(shape=(150, 150, 3))
    base = base_model(inputs, training=False)
    vectors = keras.layers.GlobalAveragePooling2D()(base)
    outputs = keras.layers.Dense(5)(vectors)
    model = keras.Model(inputs, outputs)

    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
    loss = keras.losses.CategoricalCrossentropy(from_logits=True)

    model.compile(
        optimizer=optimizer,
        loss=loss,
        metrics=['accuracy']
    )
    
    return model

# %%
scores = {}

for lr in [0.0001, 0.001, 0.01, 0.1]:
    print(lr)

    model = make_model(learning_rate=lr)
    history = model.fit(datatrain, epochs=10, validation_data=datatest)
    scores[lr] = history.history

    print()
    print()
# Out:
# 0.0001
# Epoch 1/10
# 118/118 [==============================] - 15s 109ms/step - loss: 1.3982 - accuracy: 0.4341 - val_loss: 1.0118 - val_accuracy: 0.6865
# Epoch 2/10
# 118/118 [==============================] - 12s 103ms/step - loss: 0.9653 - accuracy: 0.6637 - val_loss: 0.7728 - val_accuracy: 0.7532
# Epoch 3/10
# 118/118 [==============================] - 12s 102ms/step - loss: 0.8011 - accuracy: 0.7236 - val_loss: 0.6692 - val_accuracy: 0.7802
# Epoch 4/10
# 118/118 [==============================] - 12s 100ms/step - loss: 0.7138 - accuracy: 0.7560 - val_loss: 0.6128 - val_accuracy: 0.7856
# Epoch 5/10
# 118/118 [==============================] - 12s 100ms/step - loss: 0.6541 - accuracy: 0.7775 - val_loss: 0.5696 - val_accuracy: 0.8090
# Epoch 6/10
# 118/118 [==============================] - 12s 100ms/step - loss: 0.6116 - accuracy: 0.7903 - val_loss: 0.5427 - val_accuracy: 0.8180
# Epoch 7/10
# ...

# %%
for lr, hist in scores.items():
    plt.plot(hist['accuracy'], label=('train=%s' % lr))
    #plt.plot(hist['val_accuracy'], label=('val=%s' % lr))

plt.xticks(np.arange(10))
plt.legend()

# %%
for lr, hist in scores.items():
    #plt.plot(hist['accuracy'], label=('train=%s' % lr))
    plt.plot(hist['val_accuracy'], label=('val=%s' % lr))

plt.xticks(np.arange(10))
plt.legend()

# %%
learning_rate = 0.001

model = make_model(learning_rate=learning_rate)

history = model.fit(
    datatrain,
    epochs=10,
    validation_data=datatest
)
# Out:
# Epoch 1/10
# 118/118 [==============================] - 15s 112ms/step - loss: 0.7612 - accuracy: 0.7190 - val_loss: 0.4798 - val_accuracy: 0.8306
# Epoch 2/10
# 118/118 [==============================] - 12s 99ms/step - loss: 0.4754 - accuracy: 0.8400 - val_loss: 0.4491 - val_accuracy: 0.8414
# Epoch 3/10
# 118/118 [==============================] - 12s 103ms/step - loss: 0.3965 - accuracy: 0.8671 - val_loss: 0.4402 - val_accuracy: 0.8468
# Epoch 4/10
# 118/118 [==============================] - 12s 101ms/step - loss: 0.3516 - accuracy: 0.8838 - val_loss: 0.4392 - val_accuracy: 0.8559
# Epoch 5/10
# 118/118 [==============================] - 12s 100ms/step - loss: 0.3198 - accuracy: 0.8995 - val_loss: 0.4384 - val_accuracy: 0.8523
# Epoch 6/10
# 118/118 [==============================] - 12s 101ms/step - loss: 0.2871 - accuracy: 0.9131 - val_loss: 0.4325 - val_accuracy: 0.8541
# Epoch 7/10
# ...

# %% [markdown]
# ## Adding more layers

# %%
def make_model(learning_rate=0.01, size_inner=100):
    base_model = Xception(
        weights='imagenet',
        include_top=False,
        input_shape=(150, 150, 3)
    )

    base_model.trainable = False

    inputs = keras.Input(shape=(150, 150, 3))
    base = base_model(inputs, training=False)
    vectors = keras.layers.GlobalAveragePooling2D()(base)
    
    # adding inner layer
    inner = keras.layers.Dense(size_inner, activation='relu')(vectors)
    
    outputs = keras.layers.Dense(5)(inner)
    
    model = keras.Model(inputs, outputs)

    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
    loss = keras.losses.CategoricalCrossentropy(from_logits=True)

    model.compile(
        optimizer=optimizer,
        loss=loss,
        metrics=['accuracy']
    )
    
    return model

# %%
learning_rate = 0.001

scores = {}

for size in [10, 100, 1000]:
    print(size)

    model = make_model(learning_rate=learning_rate, size_inner=size)
    history = model.fit(datatrain, epochs=10, validation_data=datatest)
    scores[size] = history.history

    print()
    print()
# Out:
# 10
# Epoch 1/10
# 118/118 [==============================] - 15s 108ms/step - loss: 0.7971 - accuracy: 0.7076 - val_loss: 0.5000 - val_accuracy: 0.8288
# Epoch 2/10
# 118/118 [==============================] - 12s 102ms/step - loss: 0.4557 - accuracy: 0.8426 - val_loss: 0.4672 - val_accuracy: 0.8468
# Epoch 3/10
# 118/118 [==============================] - 12s 103ms/step - loss: 0.3683 - accuracy: 0.8732 - val_loss: 0.4668 - val_accuracy: 0.8595
# Epoch 4/10
# 118/118 [==============================] - 12s 102ms/step - loss: 0.3150 - accuracy: 0.8966 - val_loss: 0.4557 - val_accuracy: 0.8541
# Epoch 5/10
# 118/118 [==============================] - 12s 103ms/step - loss: 0.2736 - accuracy: 0.9078 - val_loss: 0.4782 - val_accuracy: 0.8577
# Epoch 6/10
# 118/118 [==============================] - 12s 103ms/step - loss: 0.2423 - accuracy: 0.9216 - val_loss: 0.4766 - val_accuracy: 0.8613
# Epoch 7/10
# ...

# %%
for size, hist in scores.items():
    plt.plot(hist['val_accuracy'], label=('val=%s' % size))

plt.xticks(np.arange(10))
plt.yticks([0.80, 0.825, 0.85, 0.875, 0.90])
plt.legend()

# %% [markdown]
# ## Regularization and Dropout

# %%
def make_model(learning_rate=0.01, size_inner=100, droprate=0.5):
    base_model = Xception(
        weights='imagenet',
        include_top=False,
        input_shape=(150, 150, 3)
    )

    base_model.trainable = False

    #########################################

    inputs = keras.Input(shape=(150, 150, 3))
    base = base_model(inputs, training=False)
    vectors = keras.layers.GlobalAveragePooling2D()(base)
    
    inner = keras.layers.Dense(size_inner, activation='relu')(vectors)
    drop = keras.layers.Dropout(droprate)(inner)
    
    outputs = keras.layers.Dense(5)(drop)
    
    model = keras.Model(inputs, outputs)
    
    #########################################

    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
    loss = keras.losses.CategoricalCrossentropy(from_logits=True)

    model.compile(
        optimizer=optimizer,
        loss=loss,
        metrics=['accuracy']
    )
    
    return model

# %%
learning_rate = 0.001
size = 10

scores = {}

for droprate in [0.0, 0.2, 0.5, 0.8]:
    print(droprate)

    model = make_model(
        learning_rate=learning_rate,
        size_inner=size,
        droprate=droprate
    )

    history = model.fit(datatrain, epochs=30, validation_data=datatest)
    scores[droprate] = history.history

    print()
    print()
# Out:
# 0.0
# Epoch 1/30
# 118/118 [==============================] - 15s 107ms/step - loss: 0.7787 - accuracy: 0.7081 - val_loss: 0.5074 - val_accuracy: 0.8180
# Epoch 2/30
# 118/118 [==============================] - 12s 99ms/step - loss: 0.4451 - accuracy: 0.8418 - val_loss: 0.4540 - val_accuracy: 0.8414
# Epoch 3/30
# 118/118 [==============================] - 12s 100ms/step - loss: 0.3609 - accuracy: 0.8713 - val_loss: 0.4474 - val_accuracy: 0.8432
# Epoch 4/30
# 118/118 [==============================] - 12s 99ms/step - loss: 0.3121 - accuracy: 0.8921 - val_loss: 0.4567 - val_accuracy: 0.8450
# Epoch 5/30
# 118/118 [==============================] - 12s 99ms/step - loss: 0.2673 - accuracy: 0.9131 - val_loss: 0.4764 - val_accuracy: 0.8450
# Epoch 6/30
# 118/118 [==============================] - 12s 99ms/step - loss: 0.2311 - accuracy: 0.9277 - val_loss: 0.4731 - val_accuracy: 0.8541
# Epoch 7/30
# ...

# %%
for droprate, hist in scores.items():
    plt.plot(hist['val_accuracy'], label=('val=%s' % droprate))

plt.ylim(0.78, 0.88)
plt.legend()

# %%
hist = scores[0.2]
plt.plot(hist['val_accuracy'], label=0.2)

hist = scores[0.5]
plt.plot(hist['val_accuracy'], label=0.5)

plt.legend()
#plt.plot(hist['accuracy'], label=('val=%s' % droprate))

# %% [markdown]
# ## Data Augmentation

# %%
from tensorflow.keras.applications.xception import preprocess_input

# %%
datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

datatrain = datagen.flow_from_directory(train_dir,
                                        target_size=(150, 150),
                                        batch_size=32,
                                        class_mode='categorical',
                                        shuffle = True)

datatest = datagen.flow_from_directory(test_dir,
                                       target_size=(150, 150),
                                       batch_size=32,
                                       class_mode='categorical',
                                       shuffle = False)
# Out:
# Found 3762 images belonging to 5 classes.
# Found 555 images belonging to 5 classes.

# %%
learning_rate = 0.001
size = 10
droprate = 0.2

model = make_model(
    learning_rate=learning_rate,
    size_inner=size,
    droprate=droprate
)

history = model.fit(datatrain, epochs=50, validation_data=datatest)
# Out:
# Epoch 1/50
# 118/118 [==============================] - 15s 108ms/step - loss: 1.0286 - accuracy: 0.5702 - val_loss: 0.6479 - val_accuracy: 0.7928
# Epoch 2/50
# 118/118 [==============================] - 12s 99ms/step - loss: 0.6980 - accuracy: 0.7294 - val_loss: 0.5000 - val_accuracy: 0.8288
# Epoch 3/50
# 118/118 [==============================] - 12s 100ms/step - loss: 0.5853 - accuracy: 0.7820 - val_loss: 0.4757 - val_accuracy: 0.8396
# Epoch 4/50
# 118/118 [==============================] - 12s 102ms/step - loss: 0.5135 - accuracy: 0.8115 - val_loss: 0.4632 - val_accuracy: 0.8468
# Epoch 5/50
# 118/118 [==============================] - 12s 101ms/step - loss: 0.4654 - accuracy: 0.8291 - val_loss: 0.4397 - val_accuracy: 0.8486
# Epoch 6/50
# 118/118 [==============================] - 12s 101ms/step - loss: 0.4424 - accuracy: 0.8333 - val_loss: 0.4464 - val_accuracy: 0.8505
# Epoch 7/50
# ...

# %%
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.xticks(np.arange(10))
plt.legend()

# %% [markdown]
# ## Training Larger Model

# %%
def make_model(input_size = 299, learning_rate=0.01, size_inner=100, droprate=0.5):
    base_model = Xception(
        weights='imagenet',
        include_top=False,
        input_shape=(input_size, input_size, 3)
    )

    base_model.trainable = False

    inputs = keras.Input(shape=(input_size, input_size, 3))
    base = base_model(inputs, training=False)
    vectors = keras.layers.GlobalAveragePooling2D()(base)
    
    inner = keras.layers.Dense(size_inner, activation='relu')(vectors)
    drop = keras.layers.Dropout(droprate)(inner)
    
    outputs = keras.layers.Dense(5)(drop)
    
    model = keras.Model(inputs, outputs)

    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
    loss = keras.losses.CategoricalCrossentropy(from_logits=True)

    model.compile(
        optimizer=optimizer,
        loss=loss,
        metrics=['accuracy']
    )
    
    return model

# %%
input_size = 299

datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

datatrain = datagen.flow_from_directory(train_dir,
                                        target_size=(input_size, input_size),
                                        batch_size=32,
                                        class_mode='categorical',
                                        shuffle = True)

datatest = datagen.flow_from_directory(test_dir,
                                       target_size=(input_size, input_size),
                                       batch_size=32,
                                       class_mode='categorical',
                                       shuffle = False)
# Out:
# Found 3762 images belonging to 5 classes.
# Found 555 images belonging to 5 classes.

# %%
checkpoint = keras.callbacks.ModelCheckpoint(
    'xception_{epoch:02d}_{val_accuracy:.4f}.h5',
    save_best_only=True,
    monitor='val_accuracy',
    mode='max'
)

# %%
learning_rate = 0.001
size = 10
droprate = 0.2

model = make_model(
    learning_rate=learning_rate,
    size_inner=size,
    droprate=droprate
)

history = model.fit(datatrain, epochs=30, validation_data=datatest, callbacks=[checkpoint])
# Out:
# Epoch 1/30
# 118/118 [==============================] - 33s 262ms/step - loss: 0.9171 - accuracy: 0.6438 - val_loss: 0.4337 - val_accuracy: 0.9009
# Epoch 2/30
# 118/118 [==============================] - 31s 258ms/step - loss: 0.5554 - accuracy: 0.7852 - val_loss: 0.3304 - val_accuracy: 0.9045
# Epoch 3/30
# 118/118 [==============================] - 31s 261ms/step - loss: 0.4684 - accuracy: 0.8352 - val_loss: 0.2867 - val_accuracy: 0.9207
# Epoch 4/30
# 118/118 [==============================] - 31s 259ms/step - loss: 0.4241 - accuracy: 0.8450 - val_loss: 0.2666 - val_accuracy: 0.9207
# Epoch 5/30
# 118/118 [==============================] - 31s 264ms/step - loss: 0.3790 - accuracy: 0.8687 - val_loss: 0.2573 - val_accuracy: 0.9261
# Epoch 6/30
# 118/118 [==============================] - 31s 264ms/step - loss: 0.3322 - accuracy: 0.8878 - val_loss: 0.2721 - val_accuracy: 0.9117
# Epoch 7/30
# ...

# %%
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.xticks(np.arange(30))
plt.legend()

# %% [markdown]
# ## Using the Model

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img

from tensorflow.keras.applications.xception import preprocess_input

# %%
datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

datatest = datagen.flow_from_directory(test_dir,
                                       target_size=(299, 299),
                                       batch_size=32,
                                       shuffle = False)
# Out:
# Found 555 images belonging to 5 classes.

# %%
model = keras.models.load_model('xception_05_0.9261.h5')
model.summary()
# Out:
# Model: "model_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_54 (InputLayer)       [(None, 299, 299, 3)]     0
#
#  xception (Functional)       (None, 10, 10, 2048)      20861480
#
#  global_average_pooling2d_26  (None, 2048)             0
#   (GlobalAveragePooling2D)
#
#  dense_44 (Dense)            (None, 10)                20490
#
#  dropout_14 (Dropout)        (None, 10)                0
#
#  dense_45 (Dense)            (None, 5)                 55
#
# ...
# Total params: 20,882,025
# Trainable params: 20,545
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
path = 'test/rose/118974357_0faa23cce9_n.jpg'

# %%
img = load_img(path, target_size=(299, 299))

x = np.array(img)
X = np.array([x])
X.shape
# Out:
# (1, 299, 299, 3)

# %%
X = preprocess_input(X)
pred = model.predict(X)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f06b628c160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 853ms/step

# %%
dict(zip(datatrain.class_indices, pred[0]))
# Out:
# {'daisy': -5.0046606,
#  'dandelion': -2.320822,
#  'rose': 4.767618,
#  'sunflower': -4.004467,
#  'tulip': -2.936273}
